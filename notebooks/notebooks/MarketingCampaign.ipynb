# %% [markdown]
# <a href="https://colab.research.google.com/github/xbadiam/Marketing_Campaign/blob/main/notebooks/notebooks/MarketingCampaign.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Campaña de marketing
# Aumentar las ganancias de una campaña de marketing

# %% [markdown]
# ### Contexto
#
# Un modelo de respuesta puede aumentar significativamente la eficiencia de una campaña de marketing, ya sea incrementando las respuestas o reduciendo los gastos. El objetivo es predecir quién responderá a una oferta de un producto o servicio.

# %%
# !rm -rf /content/Marketing_Campaign

! git clone https://github.com/xbadiam/Marketing_Campaign.git
# Out:
# Cloning into 'Marketing_Campaign'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 74 (delta 27), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (74/74), 2.31 MiB | 9.58 MiB/s, done.
# Resolving deltas: 100% (27/27), done.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
import plotly.express as px

# Modelado
# ==============================================================================
from sklearn.decomposition import PCA
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans

# %%
data = pd.read_csv('/content/Marketing_Campaign/outputs/output.csv')
data.head(10)
# Out:
#       Education Marital_Status   Income      Kidhome      Teenhome  \
# 0      Graduate         Single  58138.0  Without_Kid  Without_Teen
# 1      Graduate         Single  46344.0     With_Kid     With_Teen
# 2      Graduate       Together  71613.0  Without_Kid  Without_Teen
# 3      Graduate       Together  26646.0     With_Kid  Without_Teen
# 4  Postgraduate        Married  58293.0     With_Kid  Without_Teen
# 5  Postgraduate       Together  62513.0  Without_Kid     With_Teen
# 6      Graduate       Divorced  55635.0  Without_Kid     With_Teen
# 7  Postgraduate        Married  33454.0     With_Kid  Without_Teen
# 8  Postgraduate       Together  30351.0     With_Kid  Without_Teen
# 9  Postgraduate       Together   5648.0     With_Kid     With_Teen
#
#   Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  ...  \
# 0  2012-09-04       58       635         88              546  ...
# 1  2014-03-08       38        11          1                6  ...
# 2  2013-08-21       26       426         49              127  ...
# 3  2014-02-10       26        11          4               20  ...
# 4  2014-01-19       94       173         43              118  ...
# 5  2013-09-09       16       520         42               98  ...
# 6  2012-11-13       34       235         65              164  ...
# 7  2013-05-08       32        76         10               56  ...
# 8  2013-06-06       19        14          0               24  ...
# 9  2014-03-13       68        28          0                6  ...
#
#    AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Complain  Response  Age  \
# 0             0             0             0         0         1   68
# 1             0             0             0         0         0   71
# 2             0             0             0         0         0   60
# 3             0             0             0         0         0   41
# 4             0             0             0         0         0   44
# 5             0             0             0         0         0   58
# 6             0             0             0         0         0   54
# 7             0             0             0         0         0   40
# 8             0             0             0         0         1   51
# 9             0             0             0         0         0   75
#
#    Spending  Has_child  Living_With  Children
# 0      1617          0       Single         0
# 1        27          1       Single         2
# 2       776          0      Partner         0
# 3        53          1      Partner         1
# 4       422          1      Partner         1
# 5       716          1      Partner         1
# 6       590          1       Single         1
# 7       169          1      Partner         1
# 8        46          1      Partner         1
# 9        49          1      Partner         2
#
# [10 rows x 30 columns]
